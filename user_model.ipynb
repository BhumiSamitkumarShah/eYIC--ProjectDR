# %%
from keras.metrics import top_k_categorical_accuracy
from keras.applications.imagenet_utils import preprocess_input, decode_predictions
from keras.models import load_model
from keras.preprocessing import image
import numpy as np


# Load saved model
from keras.models import load_model
from keras.models import Sequential
from sklearn.metrics import accuracy_score, classification_report
model = load_model('healthcare_resnet50_30_1.h5')
# Out:
# Using TensorFlow backend.
# C:\Users\DELL-PC\Anaconda3\lib\site-packages\keras\engine\saving.py:384: UserWarning: Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
#   warnings.warn('Error in loading the saved optimizer '

# %%
img = image.load_img('sample/10_right.jpeg', target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
print(x)
pr=model.predict(x)
pr1=np.argmax(pr)
print(pr1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-914f503d7169> in <module>
# ----> 1 img = image.load_img('sample/10_right.jpeg', target_size=(224, 224))
#       2 x = image.img_to_array(img)
#       3 x = np.expand_dims(x, axis=0)
#       4 x = preprocess_input(x)
#       5 print(x)
#
# NameError: name 'image' is not defined
